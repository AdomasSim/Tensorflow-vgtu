# %% [markdown]
# # AI Learning Assistant using Gemini API
# Tensorflow course – Homework 1.2.2
#
# This notebook demonstrates an **end-to-end generative AI system** called
# **“AI Learning Assistant”**.
#
# The system:
#
# 1. Loads small teaching texts **X** from GitHub
#    (`/1.2/data/example1–3/X.txt`).
# 2. Uses **Gemini API** to generate outputs **Y**:
#    - summary (`y_summary`)
#    - quiz (`y_test`)
#    - learning plan (`y_plan`)
#    - Q&A answer (`y_chat`)
# 3. Compares the generated outputs with the reference files in `/data`.
# 4. Shows how the assistant can be used on completely **new input text**.
#
# Structure of the notebook:
#
# - **Step 1.** Load (X, y) pairs from GitHub
# - **Step 2.** Inspect examples
# - **Step 3.** Define the Gemini-based AI Learning Assistant
# - **Step 4.** End-to-end generation for examples 1–3
# - **Step 5.** Inference on new data (interactive usage)

# %%
# Step 1. Load (X, y) data from GitHub

# !git clone https://github.com/AdomasSim/Tensorflow-vgtu.git

import os
from pathlib import Path

BASE_PATH = "/content/Tensorflow-vgtu"

DATA_DIR = os.path.join(BASE_PATH, "1.2", "data")
PROMPTS_DIR = os.path.join(BASE_PATH, "1.2", "prompts")

print("Base path:", BASE_PATH)
print("Data directory:", DATA_DIR)
print("Data subfolders:", os.listdir(DATA_DIR))
print("Prompts directory:", PROMPTS_DIR)
print("Prompts files:", os.listdir(PROMPTS_DIR))
# Out:
# fatal: destination path 'Tensorflow-vgtu' already exists and is not an empty directory.
# Base path: /content/Tensorflow-vgtu
# Data directory: /content/Tensorflow-vgtu/1.2/data
# Data subfolders: ['example3', 'example2', 'example1']
# Prompts directory: /content/Tensorflow-vgtu/1.2/prompts
# Prompts files: ['test_prompt_example2.txt', 'test_prompt_example3.txt', 'test_prompt_example1.txt']

# %%
# Utility to read UTF-8 text files

def read_text_file(path: Path) -> str:
    if not path.exists():
        raise FileNotFoundError(f"File not found: {path}")
    return path.read_text(encoding="utf-8")


def load_example(example_name: str):
    """
    Load X and all Y files for one example.
    Folder layout:
      1.2/data/exampleN/X.txt
                           y_summary.txt
                           y_test.txt
                           y_plan.txt
                           y_chat.txt
    """
    example_dir = Path(DATA_DIR) / example_name

    x_path         = example_dir / "X.txt"
    y_summary_path = example_dir / "y_summary.txt"
    y_test_path    = example_dir / "y_test.txt"
    y_plan_path    = example_dir / "y_plan.txt"
    y_chat_path    = example_dir / "y_chat.txt"

    example = {
        "name": example_name,
        "X": read_text_file(x_path),
        "y_summary": read_text_file(y_summary_path) if y_summary_path.exists() else None,
        "y_test": read_text_file(y_test_path) if y_test_path.exists() else None,
        "y_plan": read_text_file(y_plan_path) if y_plan_path.exists() else None,
        "y_chat": read_text_file(y_chat_path) if y_chat_path.exists() else None,
    }
    return example


# Load all three examples

example_names = ["example1", "example2", "example3"]
examples = [load_example(name) for name in example_names]

for ex in examples:
    print(f"{ex['name']}: |X| = {len(ex['X'])} characters")
# Out:
# example1: |X| = 313 characters
# example2: |X| = 317 characters
# example3: |X| = 276 characters

# %% [markdown]
# ## Step 2. Inspect one training example
#
# We briefly inspect `example1` to understand what kind of data the agent will use:
#
# - `X.txt` – short teaching text.
# - `y_summary.txt` – target summary.
# - `y_test.txt` – target quiz (questions + options + correct answer).
# - `y_plan.txt` – target learning plan.
# - `y_chat.txt` – example of question & answer (Q&A).

# %%
ex = examples[0]  # example1

print("=== X.txt (teaching text) ===")
print(ex["X"])
print("\n=== y_summary.txt (reference) ===")
print(ex["y_summary"])
print("\n=== y_test.txt (reference) – first 400 chars ===")
print(ex["y_test"][:400], "...")
print("\n=== y_plan.txt (reference) ===")
print(ex["y_plan"])
print("\n=== y_chat.txt (reference) ===")
print(ex["y_chat"])
# Out:
# === X.txt (teaching text) ===
# Dvejetainė skaičiavimo sistema naudoja tik du skaitmenis: 0 ir 1.
# Kiekviena pozicija reiškia dvejeto laipsnį: 1, 2, 4, 8, 16 ir t.t.
# Pavyzdžiui, skaičius 5 dvejetainėje sistemoje yra 101, nes 4 + 1 = 5.
# Kompiuteriai naudoja dvejetainę sistemą, nes elektroniniai komponentai turi dvi būsenas: įjungta ir išjungta.
#
#
# === y_summary.txt (reference) ===
# Santrauka:
# Dvejetainė sistema naudoja tik skaitmenis 0 ir 1, o kiekviena pozicija atitinka dvejeto laipsnį.
# Skaičius 5 dvejetainėje sistemoje užrašomas 101, nes 4 + 1 = 5.
# Kompiuteriai remiasi dvejetaine sistema, nes elektroniniai komponentai turi dvi aiškias būsenas - įjungta ir išjungta.
#
#
# === y_test.txt (reference) – first 400 chars ===
# Testas:
#
# 1) Kiek skaitmenų naudoja dvejetainė skaičiavimo sistema?
#    A) 1
#    B) 2
#    C) 10
#    D) 16
#    Teisingas atsakymas: B
#    Paaiškinimas: Dvejetainė sistema naudoja tik 0 ir 1, todėl yra dvinarė.
#
# 2) Kokia yra skaičiaus 5 dvejetainė išraiška?
#    A) 100
#    B) 101
#    C) 110
#    D) 111
#    Teisingas atsakymas: B
#    Paaiškinimas: 101 dvejetainėje reiškia 4 + 0 + 1 = 5.
#
# 3) Kodėl kompiuteriai naudo ...
#
# === y_plan.txt (reference) ===
# Mokymosi planas:
#
# 1 žingsnis: Perskaityk teoriją apie dvejetainės sistemos esmę ir skaitmenis 0 ir 1.
# 2 žingsnis: Išmok, kaip pozicijos susietos su dvejeto laipsniais (1, 2, 4, 8, 16...).
# 3 žingsnis: Praktikuok konvertavimą iš dešimtainės sistemos į dvejetainę su 10–15 pavyzdžių.
# 4 žingsnis: Praktikuok atvirkštinį konvertavimą - iš dvejetainės į dešimtainę.
# 5 žingsnis: Susiek dvejetainės sistemos žinias su kompiuterių architektūra (bitai, baitai, registrai).
#
#
# === y_chat.txt (reference) ===
# Klausimas:
# Kodėl dvejetainėje sistemoje užtenka tik dviejų skaitmenų?
#
# AI atsakymas:
# Dvejetainėje sistemoje užtenka dviejų skaitmenų – 0 ir 1 – nes ji paremta dvejeto laipsniais.
# Kiekviena pozicija atspindi, ar atitinkamas dvejeto laipsnis yra įtrauktas (1) ar ne (0) į skaičiaus sumą.
# Tai yra patogu kompiuteriams, nes elektroniniai komponentai lengvai realizuoja dvi būsenas: yra srovė (1) arba jos nėra (0).

# %% [markdown]
# ## Step 3. Define the Gemini-based AI Learning Assistant
#
# We will use **Gemini API** as a generative model.
# For each input text **X**, the assistant will:
#
# 1. Generate a short **summary**.
# 2. Generate a **quiz** with several questions and answer options.
# 3. Generate a simple **learning plan**.
# 4. Answer a **Q&A question** about the text.
#
# Below we configure Gemini and define prompt templates.

# %%
# !pip install -q google-generativeai

import google.generativeai as genai
from google.colab import userdata
# IMPORTANT:
# Set GEMINI_API_KEY in the Colab environment before running:
#   import os
#   os.environ["GEMINI_API_KEY"] = "YOUR_API_KEY_HERE"
# (do NOT commit the key to GitHub)

api_key = userdata.get("GEMINI_API_KEY")
if not api_key:
    raise ValueError("GEMINI_API_KEY is not set in Colab secrets. Patikrink pavadinimą 'GEMINI_API_KEY'.")

genai.configure(api_key=api_key)

model = genai.GenerativeModel("gemini-2.5-flash")
print("Gemini model is ready.")
print("google-generativeai version:", genai.__version__)
# Out:
# Gemini model is ready.
# google-generativeai version: 0.8.5

# %%
for m in genai.list_models():
    print(m.name)
# Out:
# models/embedding-gecko-001
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/gemini-embedding-001
# models/aqa
# models/imagen-4.0-generate-preview-06-06
# models/imagen-4.0-ultra-generate-preview-06-06
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/gemini-2.0-flash-live-001
# models/gemini-live-2.5-flash-preview
# models/gemini-2.5-flash-live-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025

# %%
BASE_SYSTEM_PROMPT = """
Tu esi AI mokymosi asistentas.
Tavo tikslas – aiškiai ir trumpai paaiškinti pateiktą mokymo medžiagą.
Laikykis nurodyto formato ir nerašyk nereikalingų įžangų.
"""


def build_summary_prompt(document_text: str) -> str:
    return f"""{BASE_SYSTEM_PROMPT}

Užduotis: remdamasis pateiktu tekstu, parašyk trumpą santrauką.

Reikalavimai:
- 3–6 sakiniai
- tik svarbiausios idėjos
- nekurk naujų faktų

Mokymo medžiaga:
\"\"\"{document_text}\"\"\""""


def build_test_prompt(document_text: str) -> str:
    return f"""{BASE_SYSTEM_PROMPT}

Užduotis: remdamasis pateiktu tekstu, sukurk testą.

Reikalavimai:
- 3–5 klausimai
- kiekvienam klausimui 4 atsakymo variantai (A, B, C, D)
- aiškiai parašyk teisingą atsakymą
- pridėk trumpą paaiškinimą

Mokymo medžiaga:
\"\"\"{document_text}\"\"\""""


def build_plan_prompt(document_text: str) -> str:
    return f"""{BASE_SYSTEM_PROMPT}

Užduotis: sudaryk mokymosi planą šiai medžiagai išmokti.

Reikalavimai:
- 5 numeruoti žingsniai
- kiekviename žingsnyje:
  - ką daryti,
  - kiek laiko maždaug skirti,
  - koks žingsnio tikslas

Mokymo medžiaga:
\"\"\"{document_text}\"\"\""""


def build_chat_system_prompt(document_text: str) -> str:
    return f"""{BASE_SYSTEM_PROMPT}

Toliau studentas užduos klausimus apie šią mokymo medžiagą.
Atsakyk tik remdamasis žemiau pateiktu tekstu.

Mokymo medžiaga:
\"\"\"{document_text}\"\"\""""

# %%
def generate_summary(document_text: str) -> str:
    prompt = build_summary_prompt(document_text)
    response = model.generate_content(prompt)
    return response.text.strip()


def generate_test(document_text: str) -> str:
    prompt = build_test_prompt(document_text)
    response = model.generate_content(prompt)
    return response.text.strip()


def generate_plan(document_text: str) -> str:
    prompt = build_plan_prompt(document_text)
    response = model.generate_content(prompt)
    return response.text.strip()


def chat_about_document(text, question):
    prompt = f"""
Tu esi naudingas mokytojas.

Mokomoji medžiaga:
{text}

Klausimas apie šią medžiagą:
{question}

Atsakyk aiškiai, trumpai ir lietuviškai.
"""
    response = model.generate_content(prompt)
    return response.text

# %%
def parse_chat_file(y_chat_text: str):
    """
    Extract (question, answer) from y_chat.txt formatted roughly as:

    Klausimas:
    ...

    AI atsakymas:
    ...
    """
    lines = [ln.strip() for ln in y_chat_text.splitlines() if ln.strip()]
    question_lines = []
    answer_lines = []
    mode = None

    for ln in lines:
        lower = ln.lower()
        if lower.startswith("klausimas"):
            mode = "q"
            continue
        if lower.startswith("ai atsakymas"):
            mode = "a"
            continue

        if mode == "q":
            question_lines.append(ln)
        elif mode == "a":
            answer_lines.append(ln)

    question = " ".join(question_lines)
    answer = " ".join(answer_lines)
    return question, answer


# Quick sanity check for example1
q1, a1 = parse_chat_file(examples[0]["y_chat"])
print("Question from y_chat.txt:")
print(q1)
print("\nAnswer from y_chat.txt:")
print(a1)
# Out:
# Question from y_chat.txt:
# Kodėl dvejetainėje sistemoje užtenka tik dviejų skaitmenų?
#
# Answer from y_chat.txt:
# Dvejetainėje sistemoje užtenka dviejų skaitmenų – 0 ir 1 – nes ji paremta dvejeto laipsniais. Kiekviena pozicija atspindi, ar atitinkamas dvejeto laipsnis yra įtrauktas (1) ar ne (0) į skaičiaus sumą. Tai yra patogu kompiuteriams, nes elektroniniai komponentai lengvai realizuoja dvi būsenas: yra srovė (1) arba jos nėra (0).

# %% [markdown]
# ## Step 4. End-to-End generation for examples 1–3
#
# For each example we:
#
# 1. Read **X.txt** (teaching text).
# 2. Use Gemini to generate:
#    - summary,
#    - quiz,
#    - learning plan,
#    - Q&A answer.
# 3. Print the **generated** result and the **reference** result from `/data`
#    side-by-side for qualitative comparison.
#
# This demonstrates a complete end-to-end pipeline from data to AI output.

# %%
for ex in examples:
    print("=" * 100)
    print(f"EXAMPLE: {ex['name']}")
    print("=" * 100)

    print("\n--- X (teaching text) – first 400 characters ---")
    print(ex["X"][:400])
    print()

    # 1) Summary
    print(">>> Gemini summary:")
    y_summary_pred = generate_summary(ex["X"])
    print(y_summary_pred, "\n")

    if ex["y_summary"] is not None:
        print(">>> Reference y_summary.txt:")
        print(ex["y_summary"], "\n")

    # 2) Test / quiz
    print(">>> Gemini quiz (test):")
    y_test_pred = generate_test(ex["X"])
    print(y_test_pred, "\n")

    if ex["y_test"] is not None:
        print(">>> Reference y_test.txt:")
        print(ex["y_test"], "\n")

    # 3) Learning plan
    print(">>> Gemini learning plan:")
    y_plan_pred = generate_plan(ex["X"])
    print(y_plan_pred, "\n")

    if ex["y_plan"] is not None:
        print(">>> Reference y_plan.txt:")
        print(ex["y_plan"], "\n")

    # 4) Q&A chat
    if ex["y_chat"] is not None:
        question, target_answer = parse_chat_file(ex["y_chat"])
    else:
        question = "Paaiškink pagrindinę šios medžiagos idėją paprastais žodžiais."
        target_answer = None

    print(">>> Q&A demo:")
    print("Question:", question)
    y_chat_pred = chat_about_document(ex["X"], question)
    print("Gemini answer:")
    print(y_chat_pred, "\n")

    if target_answer is not None:
        print(">>> Reference answer from y_chat.txt:")
        print(target_answer, "\n")
# Out:
# ====================================================================================================
# EXAMPLE: example1
# ====================================================================================================
#
# --- X (teaching text) – first 400 characters ---
# Dvejetainė skaičiavimo sistema naudoja tik du skaitmenis: 0 ir 1.
# Kiekviena pozicija reiškia dvejeto laipsnį: 1, 2, 4, 8, 16 ir t.t.
# Pavyzdžiui, skaičius 5 dvejetainėje sistemoje yra 101, nes 4 + 1 = 5.
# Kompiuteriai naudoja dvejetainę sistemą, nes elektroniniai komponentai turi dvi būsenas: įjungta ir išjungta.
#
#
# >>> Gemini summary:
# Dvejetainė skaičiavimo sistema naudoja tik du skaitmenis – 0 ir 1. Kiekviena pozicija šioje sistemoje reiškia dvejeto laipsnį, pavyzdžiui, 1, 2, 4 ir t.t. Skaičius 5 dvejetainėje sistemoje yra 101, nes 4 + 1 = 5. Kompiuteriai naudoja dvejetainę sistemą dėl to, kad jų elektroniniai komponentai gali turėti tik dvi būsenas: įjungta arba išjungta.
#
# >>> Reference y_summary.txt:
# Santrauka:
# Dvejetainė sistema naudoja tik skaitmenis 0 ir 1, o kiekviena pozicija atitinka dvejeto laipsnį.
# Skaičius 5 dvejetainėje sistemoje užrašomas 101, nes 4 + 1 = 5.
# Kompiuteriai remiasi dvejetaine sistema, nes elektroniniai komponentai turi dvi aiškias būsenas - įjungta ir išjungta.
#
#
# >>> Gemini quiz (test):
# **Testas**
#
# **1. Kurie skaitmenys naudojami dvejetainėje skaičiavimo sistemoje?**
# A) 0, 1, 2
# B) 0, 1
# C) 1, 2
# D) 0–9
# **Teisingas atsakymas:** B
# **Paaiškinimas:** Dvejetainė skaičiavimo sistema naudoja tik du skaitmenis: 0 ir 1.
#
# **2. Kodėl kompiuteriai naudoja dvejetainę sistemą?**
# A) Nes tai yra seniausia skaičiavimo sistema.
# B) Nes ji yra greitesnė už kitas sistemas.
# C) Nes elektroniniai komponentai turi dvi būsenas: įjungta ir išjungta.
# D) Nes ji leidžia lengvai atlikti sudėtingus matematinius veiksmus.
# **Teisingas atsakymas:** C
# **Paaiškinimas:** Kompiuteriai naudoja dvejetainę sistemą, nes jų elektroniniai komponentai gali turėti tik dvi būsenas (pvz., srovė yra arba jos nėra – įjungta/išjungta).
#
# **3. Ką reiškia kiekviena pozicija dvejetainiame skaičiuje?**
# A) Dešimties laipsnį.
# B) Dviejų laipsnį.
# C) Trijų laipsnį.
# D) Penkių laipsnį.
# **Teisingas atsakymas:** B
# **Paaiškinimas:** Kiekviena pozicija dvejetainėje sistemoje reiškia dvejeto laipsnį: 1, 2, 4, 8, 16 ir t.t.
#
# **4. Kaip skaičius 5 yra užrašomas dvejetainėje sistemoje, remiantis pateiktu pavyzdžiu?**
# A) 111
# B) 011
# C) 101
# D) 100
# **Teisingas atsakymas:** C
# **Paaiškinimas:** Pavyzdyje nurodoma, kad skaičius 5 dvejetainėje sistemoje yra 101, nes 4 + 1 = 5.
#
# >>> Reference y_test.txt:
# Testas:
#
# 1) Kiek skaitmenų naudoja dvejetainė skaičiavimo sistema?
#    A) 1
#    B) 2
#    C) 10
#    D) 16
#    Teisingas atsakymas: B
#    Paaiškinimas: Dvejetainė sistema naudoja tik 0 ir 1, todėl yra dvinarė.
#
# 2) Kokia yra skaičiaus 5 dvejetainė išraiška?
#    A) 100
#    B) 101
#    C) 110
#    D) 111
#    Teisingas atsakymas: B
#    Paaiškinimas: 101 dvejetainėje reiškia 4 + 0 + 1 = 5.
#
# 3) Kodėl kompiuteriai naudoja dvejetainę sistemą?
#    A) Nes ją lengva suprasti žmonėms
#    B) Nes ji sutaupo atminties
#    C) Nes elektroniniai komponentai turi dvi būsenas
#    D) Nes taip nusprendė programuotojai
#    Teisingas atsakymas: C
#    Paaiškinimas: Dvejetainė sistema tiesiogiai atitinka įjungta/išjungta būsenas.
#
#
# >>> Gemini learning plan:
# Štai mokymosi planas:
#
# 1.  **Pagrindų supratimas**
#     *   **Ką daryti:** Atidžiai perskaityti pirmąjį sakinį ir įsisąmoninti, kad dvejetainė sistema naudoja tik du skaitmenis: 0 ir 1.
#     *   **Kiek laiko:** 5 min.
#     *   **Tikslas:** Įsisavinti esminį dvejetainės sistemos bruožą – jos skaitmenų rinkinį.
#
# 2.  **Pozicijų reikšmių įsisavinimas**
#     *   **Ką daryti:** Perskaityti antrąjį sakinį ir suprasti, kad kiekviena skaitmens pozicija reiškia dvejeto laipsnį (1, 2, 4, 8, 16 ir t. t.).
#     *   **Kiek laiko:** 10 min.
#     *   **Tikslas:** Suprasti, kaip skaitmens pozicija dvejetainiame skaičiuje nulemia jo vertę.
#
# 3.  **Pavyzdžio analizė**
#     *   **Ką daryti:** Išnagrinėti pavyzdį „skaičius 5 dvejetainėje sistemoje yra 101, nes 4 + 1 = 5“. Pabandykite mintinai susieti pozicijų reikšmes (1, 2, 4) su skaičiumi 101, kad gautumėte 5.
#     *   **Kiek laiko:** 15 min.
#     *   **Tikslas:** Praktiniu pavyzdžiu įtvirtinti supratimą apie tai, kaip pozicijų reikšmės sumuojasi į galutinį skaičių.
#
# 4.  **Taikymo srities suvokimas**
#     *   **Ką daryti:** Perskaityti paskutinį sakinį apie kompiuterių naudojimą ir elektroninių komponentų būsenas. Susieti tai su 0 ir 1 reikšmėmis.
#     *   **Kiek laiko:** 5 min.
#     *   **Tikslas:** Suprasti pagrindinę priežastį, kodėl kompiuteriuose naudojama dvejetainė sistema.
#
# 5.  **Visumos apžvalga ir savitikra**
#     *   **Ką daryti:** Mintinai apžvelgti visus punktus. Pabandykite savais žodžiais paaiškinti, kas yra dvejetainė sistema, kaip ji veikia ir kam ji reikalinga kompiuteriuose.
#     *   **Kiek laiko:** 10 min.
#     *   **Tikslas:** Įsitikinti, kad visa pateikta informacija yra aiškiai suprasta ir susieta į vientisą žinių visumą.
#
# >>> Reference y_plan.txt:
# Mokymosi planas:
#
# 1 žingsnis: Perskaityk teoriją apie dvejetainės sistemos esmę ir skaitmenis 0 ir 1.
# 2 žingsnis: Išmok, kaip pozicijos susietos su dvejeto laipsniais (1, 2, 4, 8, 16...).
# 3 žingsnis: Praktikuok konvertavimą iš dešimtainės sistemos į dvejetainę su 10–15 pavyzdžių.
# 4 žingsnis: Praktikuok atvirkštinį konvertavimą - iš dvejetainės į dešimtainę.
# 5 žingsnis: Susiek dvejetainės sistemos žinias su kompiuterių architektūra (bitai, baitai, registrai).
#
#
# >>> Q&A demo:
# Question: Kodėl dvejetainėje sistemoje užtenka tik dviejų skaitmenų?
# Gemini answer:
# Dvejetainėje sistemoje užtenka tik dviejų skaitmenų (0 ir 1), nes jie atspindi dvi pagrindines būsenas: pavyzdžiui, **įjungta (1)** ir **išjungta (0)**. Kompiuterių elektroniniai komponentai būtent šias dvi būsenas ir naudoja.
#
# >>> Reference answer from y_chat.txt:
# Dvejetainėje sistemoje užtenka dviejų skaitmenų – 0 ir 1 – nes ji paremta dvejeto laipsniais. Kiekviena pozicija atspindi, ar atitinkamas dvejeto laipsnis yra įtrauktas (1) ar ne (0) į skaičiaus sumą. Tai yra patogu kompiuteriams, nes elektroniniai komponentai lengvai realizuoja dvi būsenas: yra srovė (1) arba jos nėra (0).
#
# ====================================================================================================
# EXAMPLE: example2
# ====================================================================================================
#
# --- X (teaching text) – first 400 characters ---
# HTTP (HyperText Transfer Protocol) yra ryšio protokolas, naudojamas žiniatinklyje.
# Dažniausiai naudojami HTTP metodai yra GET, POST, PUT ir DELETE.
# GET užklausa naudojama duomenims gauti, o POST - duomenims siųsti į serverį.
# HTTP atsako kodai, tokie kaip 200, 404 ir 500, nurodo, ar užklausa pavyko, ar įvyko klaida.
#
#
# >>> Gemini summary:
# HTTP (HyperText Transfer Protocol) yra žiniatinklyje naudojamas ryšio protokolas. Dažniausi HTTP metodai yra GET, POST, PUT ir DELETE. GET metodas skirtas duomenims gauti, o POST – duomenims siųsti į serverį. HTTP atsako kodai, tokie kaip 200, 404 ir 500, nurodo užklausos sėkmę arba įvykusią klaidą.
#
# >>> Reference y_summary.txt:
# Santrauka:
# HTTP yra žiniatinklio ryšio protokolas, leidžiantis klientui ir serveriui apsikeisti duomenimis.
# Pagrindiniai metodai - GET ir POST - naudojami duomenims gauti ir siųsti.
# Atsako kodai (pvz., 200, 404, 500) informuoja apie užklausos rezultatą ir galimas klaidas.
#
#
# >>> Gemini quiz (test):
# **Testas**
#
# **1. Kas yra HTTP?**
# A) Programavimo kalba
# B) Duomenų bazės sistema
# C) Ryšio protokolas, naudojamas žiniatinklyje
# D) Operacinė sistema
#
# *Teisingas atsakymas: C*
# *Paaiškinimas: Pagal mokymo medžiagą, HTTP (HyperText Transfer Protocol) yra ryšio protokolas, naudojamas žiniatinklyje.*
#
# **2. Kuris HTTP metodas naudojamas duomenims gauti?**
# A) POST
# B) DELETE
# C) GET
# D) PUT
#
# *Teisingas atsakymas: C*
# *Paaiškinimas: Tekste nurodyta, kad GET užklausa naudojama duomenims gauti.*
#
# **3. Kuris HTTP metodas naudojamas duomenims siųsti į serverį?**
# A) GET
# B) POST
# C) DELETE
# D) PUT
#
# *Teisingas atsakymas: B*
# *Paaiškinimas: Tekste aiškiai teigiama, kad POST užklausa naudojama duomenims siųsti į serverį.*
#
# **4. Ką nurodo HTTP atsako kodai, tokie kaip 200, 404 ir 500?**
# A) Naudojamą HTTP versiją
# B) Užklausą darantį naršyklės tipą
# C) Ar užklausa pavyko, ar įvyko klaida
# D) Serverio geografinę vietą
#
# *Teisingas atsakymas: C*
# *Paaiškinimas: Mokymo medžiaga teigia, kad HTTP atsako kodai nurodo, ar užklausa pavyko, ar įvyko klaida.*
#
# >>> Reference y_test.txt:
# Testas:
#
# 1) Kam naudojamas HTTP protokolas?
#    A) Vaizdo suspaudimui
#    B) Failų šifravimui
#    C) Ryšiui žiniatinklyje tarp kliento ir serverio
#    D) Operacinių sistemų atnaujinimui
#    Teisingas atsakymas: C
#    Paaiškinimas: HTTP aprašo, kaip klientas ir serveris keičiasi žinutėmis žiniatinklyje.
#
# 2) Koks HTTP metodas dažniausiai naudojamas duomenims gauti?
#    A) POST
#    B) PUT
#    C) DELETE
#    D) GET
#    Teisingas atsakymas: D
#    Paaiškinimas: GET metodas skirtas duomenų gavimui iš serverio.
#
# 3) Ką reiškia atsako kodas 404?
#    A) Užklausa pavyko
#    B) Serverio klaida
#    C) Resursas nerastas
#    D) Netinkama užklausa
#    Teisingas atsakymas: C
#    Paaiškinimas: 404 reiškia, kad serveris nerado prašomo resurso.
#
#
# >>> Gemini learning plan:
# Štai mokymosi planas:
#
# 1.  **Kas yra HTTP?**
#     *   **Ką daryti:** Atidžiai perskaityk pirmąjį sakinį, apibrėžiantį HTTP. Pasistenk jį suformuluoti savais žodžiais.
#     *   **Kiek laiko:** 5 min.
#     *   **Tikslas:** Suprasti pagrindinę HTTP paskirtį ir kam jis naudojamas.
#
# 2.  **HTTP metodai (pavadinimai)**
#     *   **Ką daryti:** Įsimink keturių dažniausiai naudojamų HTTP metodų pavadinimus: GET, POST, PUT, DELETE.
#     *   **Kiek laiko:** 10 min.
#     *   **Tikslas:** Žinoti pagrindinius HTTP metodus vardais, net jei dar nesupranti jų detalių.
#
# 3.  **GET ir POST metodų paskirtis**
#     *   **Ką daryti:** Sutelk dėmesį į GET ir POST metodų aprašymus. Aišku atskirk, kada naudojamas GET (duomenims gauti) ir kada POST (duomenims siųsti).
#     *   **Kiek laiko:** 10 min.
#     *   **Tikslas:** Aiškiai suprasti ir atskirti GET ir POST metodų funkcijas bei jų naudojimo scenarijus.
#
# 4.  **HTTP atsako kodai**
#     *   **Ką daryti:** Perskaityk apie HTTP atsako kodus, jų paskirtį (sėkmė/klaida) ir įsimink pavyzdžius (200, 404, 500), žinodamas, kad 200 yra sėkmė, 404 – nerasta, 500 – serverio klaida.
#     *   **Kiek laiko:** 10 min.
#     *   **Tikslas:** Suprasti atsako kodų reikšmę komunikacijoje ir žinoti pateiktų pavyzdžių prasmę.
#
# 5.  **Apibendrinimas ir peržiūra**
#     *   **Ką daryti:** Perskaityk visą medžiagą dar kartą. Pabandyk savo žodžiais paaiškinti, kas yra HTTP, kokie yra pagrindiniai metodai (ypač GET ir POST) ir kokią reikšmę turi atsako kodai, net nepaminėti PUT ir DELETE detalių.
#     *   **Kiek laiko:** 15 min.
#     *   **Tikslas:** Konsoliduoti visą informaciją ir būti pasirengusiam paaiškinti pagrindinius HTTP aspektus.
#
# >>> Reference y_plan.txt:
# Mokymosi planas:
#
# 1 žingsnis: Susipažink su HTTP paskirtimi ir architektūra (klientas–serveris).
# 2 žingsnis: Išmok pagrindinius metodus (GET, POST, PUT, DELETE) ir jų paskirtį.
# 3 žingsnis: Pažvelk į praktinius pavyzdžius – naršyklės užklausos, HTTP galvutės.
# 4 žingsnis: Išmok populiariausius atsako kodus (200, 301, 400, 404, 500).
# 5 žingsnis: Naudok naršyklės „Developer Tools“ arba `curl` HTTP užklausų analizei.
#
#
# >>> Q&A demo:
# Question: Kuo skiriasi GET ir POST užklausos HTTP protokole?
# Gemini answer:
# GET užklausa naudojama **duomenims gauti** iš serverio, o POST užklausa – **duomenims siųsti** į serverį.
#
# >>> Reference answer from y_chat.txt:
# GET užklausa naudojama duomenims gauti iš serverio ir paprastai nekeičia serverio būsenos. Užklausos parametrai dažnai perduodami URL eilutėje. POST užklausa dažniausiai naudojama duomenims siųsti į serverį, pavyzdžiui, formos duomenims. Ji gali pakeisti serverio būseną (sukurti naują įrašą, išsaugoti formos duomenis) ir duomenis siunčia užklausos body dalyje.
#
# ====================================================================================================
# EXAMPLE: example3
# ====================================================================================================
#
# --- X (teaching text) – first 400 characters ---
# SQL SELECT užklausa naudojama duomenims pasirinkti iš lentelės.
# Pavyzdžiui, komanda:
# SELECT name, age FROM users WHERE age > 18;
# grąžina visus naudotojus, kurių amžius didesnis nei 18.
# Papildomai galima naudoti ORDER BY, kad surūšiuotume rezultatus pagal pasirinktą stulpelį.
#
#
# >>> Gemini summary:
# SQL SELECT užklausa naudojama duomenims atrinkti iš lentelės. Ja galima nurodyti, kuriuos stulpelius pasirinkti ir filtruoti eilutes pagal nurodytą sąlygą naudojant `WHERE` sakinį. Pavyzdžiui, `SELECT name, age FROM users WHERE age > 18;` grąžina naudotojus, vyresnius nei 18 metų. Taip pat rezultatus galima surūšiuoti pagal pasirinktą stulpelį naudojant `ORDER BY`.
#
# >>> Reference y_summary.txt:
# Santrauka:
# SQL SELECT užklausa leidžia pasirinkti konkrečius stulpelius ir eilutes iš lentelės pagal sąlygas.
# Naudojant WHERE galima filtruoti rezultatus, o ORDER BY - juos surūšiuoti.
# Pavyzdyje atrenkami visi naudotojai, vyresni nei 18 metų.
#
#
# >>> Gemini quiz (test):
# Štai testas, paremtas pateikta mokymo medžiaga:
#
# **1. Kam pirmiausia naudojama SQL `SELECT` užklausa?**
# A. Duomenims įterpti į lentelę.
# B. Duomenims ištrinti iš lentelės.
# C. Duomenims pasirinkti iš lentelės.
# D. Duomenims atnaujinti lentelėje.
#
# **Teisingas atsakymas:** C
# **Paaiškinimas:** Tekste teigiama: "SQL SELECT užklausa naudojama duomenims pasirinkti iš lentelės."
#
# **2. Ką nurodo dalis `WHERE age > 18` pavyzdyje `SELECT name, age FROM users WHERE age > 18;`?**
# A. Lentelės pavadinimą.
# B. Stulpelius, kuriuos reikia pasirinkti.
# C. Rezultatų rūšiavimo tvarką.
# D. Sąlygą, pagal kurią filtruojamos eilutės.
#
# **Teisingas atsakymas:** D
# **Paaiškinimas:** Ši dalis nurodo, kad bus grąžinti tik tie naudotojai, kurių amžius didesnis nei 18, t.y., atliekamas eilučių filtravimas pagal nurodytą sąlygą.
#
# **3. Kuris SQL raktinis žodis paminėtas rezultatams rūšiuoti?**
# A. `GROUP BY`
# B. `ORDER BY`
# C. `HAVING`
# D. `LIMIT`
#
# **Teisingas atsakymas:** B
# **Paaiškinimas:** Tekste minima: "Papildomai galima naudoti ORDER BY, kad surūšiuotume rezultatus pagal pasirinktą stulpelį."
#
# >>> Reference y_test.txt:
# Testas:
#
# 1) Kam naudojama SQL SELECT užklausa?
#    A) Lentelės sukūrimui
#    B) Duomenims pasirinkti iš lentelės
#    C) Duomenims ištrinti
#    D) Duomenų tipams aprašyti
#    Teisingas atsakymas: B
#    Paaiškinimas: SELECT komanda skirta duomenų skaitymui.
#
# 2) Ką daro WHERE sąlyga?
#    A) Nustato lentelės pavadinimą
#    B) Surūšiuoja rezultatus
#    C) Filtruoja eilutes pagal sąlygą
#    D) Pakeičia stulpelių pavadinimus
#    Teisingas atsakymas: C
#    Paaiškinimas: WHERE riboja, kurios eilutės patenka į rezultatą.
#
# 3) Kuri dalis užklausoje
#    SELECT name, age FROM users WHERE age > 18;
#    nusako lentelę?
#    A) SELECT
#    B) name, age
#    C) FROM users
#    D) WHERE age > 18
#    Teisingas atsakymas: C
#    Paaiškinimas: Po FROM nurodoma, iš kurios lentelės imami duomenys.
#
#
# >>> Gemini learning plan:
# Štai mokymosi planas:
#
# 1.  **Kas yra SQL SELECT ir jo pagrindinė paskirtis**
#     *   **Ką daryti:** Perskaitykite ir supraskite, kam naudojama `SELECT` užklausa ir kokia yra jos bendra struktūra (pvz., `SELECT stulpelis FROM lentelė;`).
#     *   **Laikas:** 5 minutės
#     *   **Tikslas:** Žinoti, kam naudojama `SELECT` užklausa ir jos pagrindinę sintaksę.
#
# 2.  **Duomenų pasirinkimas (SELECT ir FROM)**
#     *   **Ką daryti:** Atidžiai peržiūrėkite pavyzdį `SELECT name, age FROM users;` (panašiai kaip pateiktame, bet be `WHERE` dalies). Išsiaiškinkite, kaip nurodyti norimus stulpelius ir iš kurios lentelės juos pasirinkti.
#     *   **Laikas:** 10 minučių
#     *   **Tikslas:** Mokėti pasirinkti konkrečius stulpelius iš nurodytos lentelės.
#
# 3.  **Duomenų filtravimas su WHERE**
#     *   **Ką daryti:** Išnagrinėkite `WHERE age > 18;` dalį pateiktame pavyzdyje. Supraskite `WHERE` paskirtį ir kaip ji naudojama duomenims filtruoti pagal nurodytas sąlygas.
#     *   **Laikas:** 15 minučių
#     *   **Tikslas:** Suprasti ir mokėti filtruoti duomenis pagal nurodytas sąlygas naudojant `WHERE`.
#
# 4.  **Rezultatų rūšiavimas su ORDER BY**
#     *   **Ką daryti:** Perskaitykite ir supraskite, kam naudojama `ORDER BY` komanda. Pagalvokite, kaip ja galima būtų surūšiuoti pateikto pavyzdžio rezultatus (pvz., pagal vardą ar amžių).
#     *   **Laikas:** 10 minučių
#     *   **Tikslas:** Mokėti surūšiuoti užklausos rezultatus pagal pasirinktą stulpelį.
#
# 5.  **Visų komponentų sujungimas ir apžvalga**
#     *   **Ką daryti:** Peržiūrėkite visą pavyzdį: `SELECT name, age FROM users WHERE age > 18;`. Pabandykite mintyse sukurti panašią užklausą, pridedant ir `ORDER BY` (pvz., `ORDER BY name DESC;`).
#     *   **Laikas:** 10 minučių
#     *   **Tikslas:** Gebėti sujungti `SELECT`, `FROM`, `WHERE` ir `ORDER BY` į vieną užklausą ir visapusiškai suprasti jų veikimą.
#
# >>> Reference y_plan.txt:
# Mokymosi planas:
#
# 1 žingsnis: Išmok SELECT sintaksės pagrindus (SELECT, FROM).
# 2 žingsnis: Praktikuok stulpelių pasirinkimą iš vienos lentelės.
# 3 žingsnis: Įsisavink WHERE sąlygą ir įvairius operatorius (>, <, =, LIKE).
# 4 žingsnis: Pridėk ORDER BY ir išmok rūšiuoti rezultatus.
# 5 žingsnis: Sukurk keletą savo užklausų su skirtingomis lentelėmis ir sąlygomis.
#
#
# >>> Q&A demo:
# Question: Kuo naudinga ORDER BY dalis SQL SELECT užklausoje?
# Gemini answer:
# `ORDER BY` dalis yra naudinga tam, kad **surūšiuotume** (tvarkingai išdėliotume) gautus duomenis pagal pasirinktą stulpelį.
#
# Tai leidžia lengviau peržiūrėti, analizuoti ir suprasti duomenis, pateikiant juos logiška ir patogia tvarka (pvz., abėcėlės tvarka, didėjimo ar mažėjimo tvarka pagal skaičius, datą ir pan.).
#
# >>> Reference answer from y_chat.txt:
# ORDER BY dalis leidžia surūšiuoti SELECT užklausos rezultatus pagal pasirinktą stulpelį ar kelis stulpelius. Pavyzdžiui, ORDER BY age ASC surikiuos naudotojus nuo jauniausio iki vyriausio. Be ORDER BY duomenys dažnai grąžinami neprognozuojama tvarka, todėl sunkiau juos analizuoti.

# %% [markdown]
# ## Step 5. Inference on new data (interactive usage)
#
# Finally, we show how the **AI Learning Assistant** can be used on completely
# new text that is not stored in `/data`.
#
# We create a small teaching paragraph `new_X` and ask the assistant to:
#
# - create a summary,
# - suggest a quiz,
# - propose a learning plan,
# - answer a custom question from the user.

# %%
# Define a completely new teaching text (not in GitHub data)
new_X = """
Dirbtinis intelektas (DI) – tai kompiuterių mokslo sritis, kuri siekia sukurti sistemas, galinčias atlikti užduotis, reikalaujančias žmogaus intelekto: mokymąsi, sprendimų priėmimą, kalbos supratimą ar vaizdų atpažinimą. DI pagrindas yra duomenys – kuo daugiau kokybiškos informacijos turi sistema, tuo tiksliau ji gali prognozuoti, klasifikuoti ar generuoti naują turinį.

DI galima suskirstyti į kelias kategorijas. Silpnas DI (angl. narrow AI) atlieka tik vieną konkrečią funkciją, pvz., rekomenduoja filmus, atpažįsta veidus ar prognozuoja kainas. Stiprus DI (angl. general AI) – teorinė koncepcija, kurioje sistema gebėtų mąstyti kaip žmogus, tačiau tokios technologijos šiandien dar nėra sukurtos.

Viena svarbiausių DI šakų – mašininis mokymasis. Tai metodas, kai modeliai mokomi iš duomenų, ieškodami pasikartojančių dėsningumų. Dar gilesnė sritis – gilusis mokymasis, paremtas dirbtiniais neuroniniais tinklais, kurie sudaryti iš daug sluoksnių ir imituoja žmogaus smegenų veikimą. Tokie modeliai geba analizuoti sudėtingus signalus, pvz., kalbą, tekstą, vaizdus ar garsą.

Šiuolaikinės generatyvinės DI sistemos, tokios kaip „ChatGPT“ ar „Gemini“, ne tik analizuoja informaciją, bet ir sukuria naują turinį: rašo tekstus, kuria vaizdus, programuoja ar net generuoja mokymosi planus. Nors jos labai naudingos, svarbu suprasti, kad jos gali klysti, todėl žmogaus priežiūra ir kritinis mąstymas išlieka būtini.
"""

print("=== New X text ===")
print(new_X)

print("\n--- Summary ---")
print(generate_summary(new_X))

print("\n--- Quiz ---")
print(generate_test(new_X))

print("\n--- Learning plan ---")
print(generate_plan(new_X))

print("\n--- Q&A ---")
user_question = "Kuo skiriasi GET ir POST užklausos šioje medžiagoje?"
print("User question:", user_question)
print("Assistant answer:")
print(chat_about_document(new_X, user_question))
# Out:
# === New X text ===
#
# Dirbtinis intelektas (DI) – tai kompiuterių mokslo sritis, kuri siekia sukurti sistemas, galinčias atlikti užduotis, reikalaujančias žmogaus intelekto: mokymąsi, sprendimų priėmimą, kalbos supratimą ar vaizdų atpažinimą. DI pagrindas yra duomenys – kuo daugiau kokybiškos informacijos turi sistema, tuo tiksliau ji gali prognozuoti, klasifikuoti ar generuoti naują turinį.
#
# DI galima suskirstyti į kelias kategorijas. Silpnas DI (angl. narrow AI) atlieka tik vieną konkrečią funkciją, pvz., rekomenduoja filmus, atpažįsta veidus ar prognozuoja kainas. Stiprus DI (angl. general AI) – teorinė koncepcija, kurioje sistema gebėtų mąstyti kaip žmogus, tačiau tokios technologijos šiandien dar nėra sukurtos.
#
# Viena svarbiausių DI šakų – mašininis mokymasis. Tai metodas, kai modeliai mokomi iš duomenų, ieškodami pasikartojančių dėsningumų. Dar gilesnė sritis – gilusis mokymasis, paremtas dirbtiniais neuroniniais tinklais, kurie sudaryti iš daug sluoksnių ir imituoja žmogaus smegenų veikimą. Tokie modeliai geba analizuoti sudėtingus signalus, pvz., kalbą, tekstą, vaizdus ar garsą.
#
# Šiuolaikinės generatyvinės DI sistemos, tokios kaip „ChatGPT“ ar „Gemini“, ne tik analizuoja informaciją, bet ir sukuria naują turinį: rašo tekstus, kuria vaizdus, programuoja ar net generuoja mokymosi planus. Nors jos labai naudingos, svarbu suprasti, kad jos gali klysti, todėl žmogaus priežiūra ir kritinis mąstymas išlieka būtini.
#
#
# --- Summary ---
# Dirbtinis intelektas (DI) yra kompiuterių mokslo sritis, kurianti sistemas, galinčias atlikti žmogaus intelekto reikalaujančias užduotis, o jo pagrindas yra duomenys. DI skirstomas į silpnąjį DI, atliekantį konkrečias funkcijas, ir teorinį stiprųjį DI, kuris dar nėra sukurtas. Svarbiausios DI šakos yra mašininis mokymasis, leidžiantis modeliams mokytis iš duomenų, ir gilusis mokymasis, naudojantis dirbtinius neuroninius tinklus sudėtingiems signalams analizuoti. Šiuolaikinės generatyvinės DI sistemos ne tik analizuoja, bet ir kuria naują turinį, tačiau jos gali klysti, todėl būtina žmogaus priežiūra ir kritinis mąstymas.
#
# --- Quiz ---
# Štai testas, sukurtas remiantis pateikta mokymo medžiaga:
#
# **1. Kas yra Dirbtinis intelektas (DI) ir kokios jo pagrindinės užduotys?**
# A) Tai technologija, skirta tik žaidimams kurti.
# B) Tai kompiuterių mokslo sritis, siekianti sukurti sistemas, galinčias atlikti užduotis, reikalaujančias žmogaus intelekto.
# C) Tai programa, kuri tik renka duomenis, bet jų neanalizuoja.
# D) Tai prietaisas, skirtas tik robotams valdyti.
#
# **Teisingas atsakymas: B**
# *Paaiškinimas*: Tekste nurodoma, kad DI – tai kompiuterių mokslo sritis, kuri siekia sukurti sistemas, galinčias atlikti užduotis, reikalaujančias žmogaus intelekto.
#
# **2. Kuo skiriasi Silpnas DI (angl. narrow AI) nuo Stipraus DI (angl. general AI) pagal pateiktą tekstą?**
# A) Silpnas DI yra senesnė technologija, o Stiprus DI – naujesnė.
# B) Silpnas DI atlieka tik vieną konkrečią funkciją, o Stiprus DI gebėtų mąstyti kaip žmogus (teorinė koncepcija).
# C) Silpnas DI reikalauja daugiau duomenų nei Stiprus DI.
# D) Silpnas DI yra teorinė koncepcija, o Stiprus DI jau yra sukurtas.
#
# **Teisingas atsakymas: B**
# *Paaiškinimas*: Tekstas aiškiai apibrėžia, kad "Silpnas DI (...) atlieka tik vieną konkrečią funkciją", o "Stiprus DI (...) – teorinė koncepcija, kurioje sistema gebėtų mąstyti kaip žmogus".
#
# **3. Kas yra gilusis mokymasis (deep learning) ir koks jo pagrindinis principas?**
# A) Tai metodas, kuris mokosi tik iš struktūrizuotų duomenų lentelių.
# B) Tai mašininio mokymosi atšaka, paremta dirbtiniais neuroniniais tinklais, imituojančiais žmogaus smegenų veikimą.
# C) Tai technologija, naudojama tik filmų rekomendacijoms kurti.
# D) Tai sistema, kuri gali generuoti naują turinį be jokios žmogaus priežiūros.
#
# **Teisingas atsakymas: B**
# *Paaiškinimas*: Tekste rašoma: "Dar gilesnė sritis – gilusis mokymasis, paremtas dirbtiniais neuroniniais tinklais, kurie sudaryti iš daug sluoksnių ir imituoja žmogaus smegenų veikimą."
#
# **4. Koks svarbus perspėjimas susijęs su šiuolaikinėmis generatyvinėmis DI sistemomis (pvz., ChatGPT ar Gemini)?**
# A) Jos gali tik analizuoti informaciją, bet nekuria naujo turinio.
# B) Jos veikia be klaidų ir nereikalauja jokios žmogaus priežiūros.
# C) Jos gali klysti, todėl žmogaus priežiūra ir kritinis mąstymas išlieka būtini.
# D) Jų pagrindinis tikslas – tik prognozuoti kainas rinkoje.
#
# **Teisingas atsakymas: C**
# *Paaiškinimas*: Tekstas teigia: "Nors jos labai naudingos, svarbu suprasti, kad jos gali klysti, todėl žmogaus priežiūra ir kritinis mąstymas išlieka būtini."
#
# --- Learning plan ---
# Štai mokymosi planas:
#
# 1.  **Susipažinimas su DI apibrėžimu ir pagrindais.**
#     *   **Ką daryti:** Atidžiai perskaitykite pirmą pastraipą. Sutelkite dėmesį į tai, kas yra DI, kokius uždavinius jis atlieka ir kodėl duomenys yra jo pagrindas. Mintyse suformuluokite savo DI apibrėžimą.
#     *   **Kiek laiko:** 10 minučių.
#     *   **Tikslas:** Suprasti esminę DI sampratą ir jo veikimo principų pagrindą.
#
# 2.  **DI kategorijų atskyrimas.**
#     *   **Ką daryti:** Perskaitykite antrą pastraipą. Įsidėmėkite skirtumus tarp „silpnojo“ (narrow AI) ir „stipriojo“ (general AI) DI. Pabandykite pateikti po vieną savo pavyzdį kiekvienai kategorijai.
#     *   **Kiek laiko:** 10 minučių.
#     *   **Tikslas:** Aiškiai atskirti ir suprasti skirtingas DI rūšis.
#
# 3.  **Pagrindinių DI šakų – mašininio ir giliojo mokymosi – įsisavinimas.**
#     *   **Ką daryti:** Perskaitykite trečią pastraipą. Supraskite, kas yra mašininis mokymasis ir kaip jis veikia. Giliajam mokymuisi skirkite ypatingą dėmesį – atkreipkite dėmesį į neuroninių tinklų svarbą ir jų galimybes.
#     *   **Kiek laiko:** 15 minučių.
#     *   **Tikslas:** Suprasti dvi svarbiausias DI metodologijas ir jų esminius skirtumus.
#
# 4.  **Šiuolaikinių generatyvinių DI sistemų ir jų apribojimų supratimas.**
#     *   **Ką daryti:** Perskaitykite ketvirtą pastraipą. Įsidėmėkite generatyvinių DI sistemų pavyzdžius (pvz., „ChatGPT“) ir jų naujas funkcijas (turinio generavimas). Taip pat atkreipkite dėmesį į kritinį mąstymą ir žmogaus priežiūros svarbą.
#     *   **Kiek laiko:** 10 minučių.
#     *   **Tikslas:** Susipažinti su naujausiomis DI tendencijomis ir suprasti jų galimybes bei rizikas.
#
# 5.  **Apibendrinimas ir savikontrolė.**
#     *   **Ką daryti:** Iš naujo peržvelkite visą medžiagą. Pabandykite trumpai atsakyti į šiuos klausimus: Kas yra DI? Kuo skiriasi silpnas ir stiprus DI? Kas yra mašininis ir gilusis mokymasis? Kokios yra generatyvinio DI galimybės ir apribojimai? Jei į kurį nors klausimą atsakyti sunku, dar kartą perskaitykite atitinkamą dalį.
#     *   **Kiek laiko:** 15 minučių.
#     *   **Tikslas:** Įtvirtinti įgytas žinias ir įsitikinti, kad visa medžiaga yra suprasta.
#
# --- Q&A ---
# User question: Kuo skiriasi GET ir POST užklausos šioje medžiagoje?
# Assistant answer:
# Šioje mokomojoje medžiagoje nėra informacijos apie GET ir POST užklausas. Pateiktoje medžiagoje aptariamas dirbtinis intelektas, jo rūšys ir veikimo principai, bet ne konkrečios interneto užklausų metodikos.

# %% [markdown]
# ## Conclusions
#
# In this notebook we implemented an **end-to-end generative AI system**:
#
# - Input **X**: short teaching texts stored in GitHub (`/1.2/data/example1–3/X.txt`).
# - Output **Y**: summary, quiz, learning plan, and Q&A answer generated using **Gemini API**.
# - We compared Gemini outputs with reference files (`y_summary.txt`, `y_test.txt`, `y_plan.txt`, `y_chat.txt`).
# - We also showed how the same agent can be used on completely new data
#   outside the training examples.
#
# This Colab notebook can now be saved as `.ipynb` and uploaded to the
# `Tensorflow-vgtu` GitHub repository as the deliverable for task **1.2.2**.
